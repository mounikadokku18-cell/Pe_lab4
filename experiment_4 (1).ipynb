# %%
# !pip install groq transformers -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 6.6 MB/s eta 0:00:00

# %%
from google.colab import userdata
from groq import Groq

# %%
api_key = userdata.get("GROQ_API_KEY")
client = Groq(api_key=api_key)

# %%
# ---------------------------------------
# Prompt 1 - Vague Prompt
# ---------------------------------------

vague_prompt = "Tell me about Java."

response1 = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": vague_prompt}
    ]
)

# ---------------------------------------
# Prompt 2 - Improved Prompt
# ---------------------------------------

improved_prompt = """
You are a computer science teacher.

Explain the Java programming language.

Include:
1. Definition
2. Features
3. Applications

Use simple English.
Write the answer in 5 bullet points.
"""

response2 = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": improved_prompt}
    ]
)

# ---------------------------------------
# Display Results
# ---------------------------------------

print("========== Vague Prompt ==========\n")
print(vague_prompt)

print("\nOutput:\n")
print(response1.choices[0].message.content)

print("\n\n========== Improved Prompt ==========\n")
print(improved_prompt)

print("\nOutput:\n")
print(response2.choices[0].message.content)
# Out:
# ========== Vague Prompt ==========
#
# Tell me about Java.
#
# Output:
#
# **Introduction to Java**
# ========================
#
# Java is a high-level, object-oriented programming language developed by Sun Microsystems (now owned by Oracle Corporation). It was first released in 1995 and has since become one of the most popular programming languages in the world.
#
# **Key Features of Java**
# ------------------------
#
# * **Platform Independence**: Java is known for its "write once, run anywhere" philosophy, which means that Java code can run on any device that has a Java Virtual Machine (JVM) installed, regardless of the underlying operating system.
# * **Object-Oriented**: Java is an object-oriented language, which means it organizes code into objects that contain data and functions that operate on that data.
# * **Simple and Familiar Syntax**: Java's syntax is based on C++ and is relatively simple and easy to learn.
# * **Robust Security**: Java has a robust security system that includes memory management, data type checking, and secure class loading.
# * **Large Community**: Java has a large and active community of developers, which means there are many resources available for learning and troubleshooting.
#
# **Common Use Cases for Java**
# -----------------------------
#
# * **Android App Development**: Java is widely used for developing Android apps, as it is the primary language for Android development.
# * **Web Development**: Java is used for developing web applications, especially those that require complex business logic and high-performance.
# * **Enterprise Software**: Java is widely used in enterprise software development, especially for large-scale systems that require high reliability and scalability.
# * **Machine Learning and Data Science**: Java is used in machine learning and data science applications, especially those that require high-performance and scalability.
#
# **Java Ecosystem**
# -----------------
#
# * **Java Standard Edition (SE)**: This is the core Java platform, which includes the Java Runtime Environment (JRE) and the Java Development Kit (JDK).
# * **Java Enterprise Edition (EE)**: This is an extended version of Java SE, which includes additional features and APIs for developing enterprise-level applications.
# * **Java Micro Edition (ME)**: This is a subset of Java SE, which is designed for developing applications for small devices such as mobile phones and embedded systems.
#
# **Getting Started with Java**
# -----------------------------
#
# To get started with Java, you will need to:
#
# 1. **Install the Java Development Kit (JDK)**: This includes the Java compiler, runtime environment, and other development tools.
# 2. **Choose an Integrated Development Environment (IDE)**: Popular IDEs for Java include Eclipse, NetBeans, and IntelliJ IDEA.
# 3. **Learn the Basics of Java**: Start with basic tutorials and examples, and gradually move on to more advanced topics.
#
# **Resources for Learning Java**
# -------------------------------
#
# * **Official Java Tutorials**: The official Java website provides extensive tutorials and guides for learning Java.
# * **Udemy and Coursera Courses**: There are many online courses available for learning Java, including courses on Udemy and Coursera.
# * **Java Books**: There are many books available for learning Java, including "Head First Java" and "Java: A Beginner's Guide".
#
#
# ========== Improved Prompt ==========
#
#
# You are a computer science teacher.
#
# Explain the Java programming language.
#
# Include:
# 1. Definition
# 2. Features
# 3. Applications
#
# Use simple English.
# Write the answer in 5 bullet points.
#
#
# Output:
#
# Here's an explanation of the Java programming language:
#
# * **Definition**: Java is a computer programming language that lets us create instructions that a computer can understand. It's like a set of rules that tells the computer what to do. Java was created to make it easy to write programs that can run on many different types of computers.
# * **Features**: Java has many useful features, such as being "object-oriented", which means it organizes code into small, reusable pieces called "objects". Java is also a "platform-independent" language, which means that programs written in Java can run on many different types of computers, like Windows, Mac, or Linux.
# * **Key Aspect**: Java is a "high-level" language, which means it's easy for humans to read and write, and it's not too close to the computer's native language, called "machine code". This makes Java a popular choice for many programmers.
# * **Applications**: Java is used in many real-world applications, such as creating games, mobile apps, and web applications. For example, many Android apps are written in Java, and popular websites like Amazon and Google use Java to power their services.
# * **Uses**: Java is also used in other areas, such as creating desktop applications, like media players and IDEs (Integrated Development Environments), and even in enterprise software, like banking and financial systems, due to its strong security features and ability to handle large amounts of data.
